# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/LENOVO/Downloads/example_data_jan.csv")
df.head(10)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_6992\1073565398.py:1: DtypeWarning: Columns (14,16,28,48,50,55,67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/LENOVO/Downloads/example_data_jan.csv")
#    battery_heater_on  battery_level  battery_range  charge_amps  \
# 0              False             66         218.15           48
# 1              False             66         218.15           48
# 2              False             66         218.15           48
# 3              False             66         218.15           48
# 4              False             66         218.15           48
# 5              False             66         218.15           48
# 6              False             66         218.15           48
# 7              False             66         218.15           48
# 8              False             66         218.15           48
# 9              False             66         218.15           48
#
# ...

# %%
df.columns
# Out:
# Index(['battery_heater_on', 'battery_level', 'battery_range', 'charge_amps',
#        'charge_current_request', 'charge_current_request_max',
#        'charge_enable_request', 'charge_energy_added', 'charge_limit_soc',
#        'charge_limit_soc_max',
#        ...
#        'tpms_soft_warning_fl', 'tpms_soft_warning_fr', 'tpms_soft_warning_rl',
#        'tpms_soft_warning_rr', 'valet_mode', 'valet_pin_needed',
#        'vehicle_name', 'vehicle_self_test_progress',
#        'vehicle_self_test_requested', 'webcam_available'],
#       dtype='object', length=215)
