# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv')
#df.head(10)

df.iloc[:,:11].head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  condition
# 0      5650     1.0           0     0          3
# ...

# %%
df.iloc[:,11:].head(10)
# Out:
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7        1180              0      1955             0    98178  47.5112
# 1      7        2170            400      1951          1991    98125  47.7210
# 2      6         770              0      1933             0    98028  47.7379
# 3      7        1050            910      1965             0    98136  47.5208
# 4      8        1680              0      1987             0    98074  47.6168
# 5     11        3890           1530      2001             0    98053  47.6561
# 6      7        1715              0      1995             0    98003  47.3097
# 7      7        1060              0      1963             0    98198  47.4095
# 8      7        1050            730      1960             0    98146  47.5123
# 9      7        1890              0      2003             0    98038  47.3684
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# ...

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#Which are the input and output variables
#Relationships between input and output variables
#Insightful questions for the dataset

#Q> The different price ranged houses based on their sqft and bedrooms (Inputs: bedrooms, sqft, Outputs: selection(price))

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
plt.hist(df['price'])
# Out:
# (array([1.9021e+04, 2.1480e+03, 3.1600e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <a list of 10 Patch objects>)

# %%
#univariate analysis
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
outlier_bedroom = df[df['bedrooms'] == 33]
outlier_bedroom.head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15870 -122.331           1330        4700
#
# [1 rows x 21 columns]

# %%
df['bedrooms'] = df['bedrooms'].replace(33,3)
df[df['id'] == 2402100895]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 15870  2402100895  20140625T000000  640000.0         3       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 15870 -122.331           1330        4700
#
# [1 rows x 21 columns]

# %%
sns.boxplot(df['bathrooms'])

# %%
df[df['bathrooms'] > 3.5].describe()
# Out:
#                  id         price    bedrooms   bathrooms   sqft_living  \
# count  5.570000e+02  5.570000e+02  557.000000  557.000000    557.000000
# mean   3.835341e+09  1.440567e+06    4.701975    4.268851   4400.797127
# std    2.824372e+09  9.427293e+05    1.051316    0.612265   1391.095737
# min    4.200013e+07  2.550000e+05    3.000000    3.750000   1390.000000
# 25%    1.454600e+09  8.500000e+05    4.000000    3.750000   3530.000000
# 50%    3.262301e+09  1.169000e+06    5.000000    4.000000   4210.000000
# 75%    5.700004e+09  1.750000e+06    5.000000    4.500000   5040.000000
# max    9.831200e+09  7.700000e+06   10.000000    8.000000  13540.000000
#
#             sqft_lot      floors  waterfront        view   condition  \
# count     557.000000  557.000000  557.000000  557.000000  557.000000
# mean    32922.026930    1.954219    0.046679    0.915619    3.267504
# std     78642.846485    0.416785    0.211139    1.413599    0.567624
# ...

# %%
outlier_bath = df[df['bathrooms'] > 3.5]['price']
sns.boxplot(outlier_bath)

# %%
values_to_replace = df[df['bathrooms'] > 3.5].index

df.loc[values_to_replace,'bathrooms'] = 3.5

# %%
from scipy import stats

df['sqft_living_winsorized'] = stats.mstats.winsorize(df['sqft_living'], limits=[0,0.01])

df[['sqft_living','sqft_living_winsorized']].sort_values('sqft_living', ascending=False)
# Out:
#        sqft_living  sqft_living_winsorized
# 12777        13540                    4980
# 7252         12050                    4980
# 3914         10040                    4980
# 9254          9890                    4980
# 8092          9640                    4980
# ...            ...                     ...
# 4868           390                     390
# 18379          384                     384
# 860            380                     380
# 15381          370                     370
# 19452          290                     290
#
# [21613 rows x 2 columns]

# %%
data_type = df['sqft_living'].dtype
data_type
# Out:
# dtype('int64')

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df.iloc[:,2:].corr(), annot=True)
