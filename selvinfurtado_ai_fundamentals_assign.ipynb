# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
selfcar_df = pd.read_excel("C:/Users/LENOVO/Downloads/AI_Fundamentals_Human_Survey_Data.xlsx")

selfcar_df.head(10)
# Out:
#    Unnamed: 0    QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99  \
# 0           0  100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC
# 1           1  100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone
# 2           2  100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone
# 3           3  100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC
# 4           4  100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC
# 5           5  100803 2021-11-03 19:22:44 2021-11-03 19:41:04       Laptop/PC
# 6           6  101224 2021-11-03 18:18:21 2021-11-03 18:33:41      Smartphone
# 7           7  101437 2021-11-04 11:44:54 2021-11-04 12:09:16       Laptop/PC
# 8           8  101485 2021-11-02 19:22:24 2021-11-02 19:35:23      Smartphone
# 9           9  101493 2021-11-02 12:19:47 2021-11-02 13:42:56       Laptop/PC
#
#   LANG_W99 FORM_W99    XTABLET_W99                            TECH1_W99  \
# 0  English   Form 2  Non-tablet HH                                  NaN
# 1  English   Form 1  Non-tablet HH                      Mostly positive
# 2  English   Form 1  Non-tablet HH                      Mostly positive
# 3  English   Form 2  Non-tablet HH                                  NaN
# 4  English   Form 2  Non-tablet HH                                  NaN
# 5  English   Form 1  Non-tablet HH                      Mostly positive
# 6  English   Form 1  Non-tablet HH                      Mostly negative
# 7  English   Form 2  Non-tablet HH                                  NaN
# 8  English   Form 1  Non-tablet HH  Equal positive and negative effects
# 9  English   Form 2  Non-tablet HH                                  NaN
#
#                                SC1_W99  ...       F_PARTYLN_FINAL  \
# 0                      Mostly positive  ...                   NaN
# 1                                  NaN  ...                   NaN
# 2                                  NaN  ...                   NaN
# 3                      Mostly positive  ...                   NaN
# 4  Equal positive and negative effects  ...  The Republican Party
# 5                                  NaN  ...                   NaN
# 6                                  NaN  ...                   NaN
# 7                      Mostly negative  ...  The Republican Party
# 8                                  NaN  ...                   NaN
# 9                      Mostly negative  ...                   NaN
#
#   F_PARTYSUM_FINAL            F_PARTYSUMIDEO_FINAL  \
# 0     Rep/Lean Rep           Conservative Rep/Lean
# 1     Rep/Lean Rep       Moderate/Liberal Rep/Lean
# 2     Dem/Lean Dem  Moderate/Conservative Dem/Lean
# 3     Rep/Lean Rep           Conservative Rep/Lean
# 4     Rep/Lean Rep           Conservative Rep/Lean
# 5     Rep/Lean Rep           Conservative Rep/Lean
# 6     Rep/Lean Rep           Conservative Rep/Lean
# 7     Rep/Lean Rep           Conservative Rep/Lean
# 8     Rep/Lean Rep           Conservative Rep/Lean
# 9     Rep/Lean Rep           Conservative Rep/Lean
#
#                      F_INC_SDT1  \
# 0  $50,000 to less than $60,000
# 1  $40,000 to less than $50,000
# 2              $100,000 or more
# 3              $100,000 or more
# 4  $30,000 to less than $40,000
# 5              $100,000 or more
# 6  $40,000 to less than $50,000
# 7             Less than $30,000
# 8              $100,000 or more
# 9  $70,000 to less than $80,000
#
#                                                F_REG             F_IDEO  \
# 0  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 5  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 6  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 7  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 8  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 9  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
#
#               F_INTFREQ F_VOLSUM    F_INC_TIER2 WEIGHT_W99
# 0   Several times a day       No  Middle income   0.206396
# 1   Several times a day      Yes  Middle income   0.315090
# 2   Several times a day       No   Upper income   0.829579
# 3   Several times a day      Yes   Upper income   0.337527
# 4            Less often       No   Lower income   1.210606
# 5  Several times a week      Yes   Upper income   0.302004
# 6      About once a day      Yes  Middle income   0.287719
# 7   Several times a day       No  Middle income   0.397488
# 8     Almost constantly      Yes   Upper income   0.276541
# 9   Several times a day       No  Middle income   0.348764
#
# [10 rows x 215 columns]

# %%
intro_df = selfcar_df.iloc[:,1:8]
intro_df
# Out:
#                QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99  \
# 0            100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC
# 1            100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone
# 2            100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone
# 3            100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC
# 4            100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC
# ...             ...                 ...                 ...             ...
# 10255  202101013246 2021-11-02 15:06:47 2021-11-02 15:21:18      Smartphone
# 10256  202101013292 2021-11-02 12:18:58 2021-11-02 12:32:49      Smartphone
# 10257  202101013344 2021-11-04 16:30:29 2021-11-06 11:08:56      Smartphone
# 10258  202101013446 2021-11-06 15:22:13 2021-11-06 16:10:36       Laptop/PC
# 10259  202101013477 2021-11-02 23:46:38 2021-11-02 23:56:21      Smartphone
#
#       LANG_W99 FORM_W99    XTABLET_W99
# 0      English   Form 2  Non-tablet HH
# 1      English   Form 1  Non-tablet HH
# 2      English   Form 1  Non-tablet HH
# 3      English   Form 2  Non-tablet HH
# 4      English   Form 2  Non-tablet HH
# ...        ...      ...            ...
# 10255  English   Form 2  Non-tablet HH
# 10256  English   Form 2  Non-tablet HH
# 10257  English   Form 1  Non-tablet HH
# 10258  English   Form 1  Non-tablet HH
# 10259  English   Form 1  Non-tablet HH
#
# [10260 rows x 7 columns]

# %%
selfcar_df.dtypes
# Out:
# Unnamed: 0                      int64
# QKEY                            int64
# INTERVIEW_START_W99    datetime64[ns]
# INTERVIEW_END_W99      datetime64[ns]
# DEVICE_TYPE_W99                object
#                             ...
# F_IDEO                         object
# F_INTFREQ                      object
# F_VOLSUM                       object
# F_INC_TIER2                    object
# WEIGHT_W99                    float64
# Length: 215, dtype: object

# %%
#selfcar_columns = [col for col in selfcar_df.columns if col.startswith('DC_')]
#selfcar_columns = selfcar_df.columns.str.startswith('DC_')
selfcar_columns = selfcar_df.iloc[:,88:113]
print(selfcar_columns)
# Out:
#       DCARS1_W99             DCARS2_W99         DCARS3_W99  \
# 0            NaN                    NaN                NaN
# 1       A little               Not sure  Probably NOT want
# 2       A little  Good idea for society      Probably want
# 3            NaN                    NaN                NaN
# 4            NaN                    NaN                NaN
# ...          ...                    ...                ...
# 10255        NaN                    NaN                NaN
# 10256        NaN                    NaN                NaN
# 10257      A lot  Good idea for society    Definitely want
# 10258   A little  Good idea for society    Definitely want
# 10259   A little               Not sure  Probably NOT want
#
#                     DCARS4_a_W99               DCARS4_b_W99  \
# 0                            NaN                        NaN
# 1          Probably would happen      Probably would happen
# 2        Definitely would happen    Definitely would happen
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 10255                        NaN                        NaN
# 10256                        NaN                        NaN
# 10257    Definitely would happen    Definitely would happen
# 10258    Definitely would happen      Probably would happen
# 10259  Probably would NOT happen  Probably would NOT happen
#
#                     DCARS4_c_W99             DCARS4_d_W99  \
# 0                            NaN                      NaN
# 1      Probably would NOT happen    Probably would happen
# 2          Probably would happen    Probably would happen
# 3                            NaN                      NaN
# 4                            NaN                      NaN
# ...                          ...                      ...
# 10255                        NaN                      NaN
# 10256                        NaN                      NaN
# 10257    Definitely would happen  Definitely would happen
# 10258      Probably would happen    Probably would happen
# 10259      Probably would happen    Probably would happen
#
#                                               DCARS5_W99  \
# 0                                                    NaN
# 1                               Not make much difference
# 2      Increase the gap between higher and lower-inco...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10255                                                NaN
# 10256                                                NaN
# 10257  Increase the gap between higher and lower-inco...
# 10258  Decrease the gap between higher and lower-inco...
# 10259                           Not make much difference
#
#                                               DCARS6_W99  \
# 0                                                    NaN
# 1      Increase the number of people killed or injure...
# 2      Decrease the number of people killed or injure...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 10255                                                NaN
# 10256                                                NaN
# 10257  Increase the number of people killed or injure...
# 10258  Decrease the number of people killed or injure...
# 10259                                            Refused
#
#                          DCARS7_W99  ...  \
# 0                               NaN  ...
# 1          The vehicle’s passengers  ...
# 2                          Not sure  ...
# 3                               NaN  ...
# 4                               NaN  ...
# ...                             ...  ...
# 10255                           NaN  ...
# 10256                           NaN  ...
# 10257  Those outside of the vehicle  ...
# 10258                      Not sure  ...
# 10259      The vehicle’s passengers  ...
#
#                                              DCARS10_W99    DCARS11_a_W99  \
# 0                                                    NaN              NaN
# 1      A higher standard than used for regular passen...  More acceptable
# 2      A higher standard than used for regular passen...  More acceptable
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 10255                                                NaN              NaN
# 10256                                                NaN              NaN
# 10257  A higher standard than used for regular passen...  More acceptable
# 10258  A higher standard than used for regular passen...  More acceptable
# 10259  A higher standard than used for regular passen...  More acceptable
#
#          DCARS11_b_W99    DCARS11_c_W99    DCARS11_d_W99  \
# 0                  NaN              NaN              NaN
# 1      More acceptable    No difference  More acceptable
# 2      More acceptable  More acceptable  More acceptable
# 3                  NaN              NaN              NaN
# 4                  NaN              NaN              NaN
# ...                ...              ...              ...
# 10255              NaN              NaN              NaN
# 10256              NaN              NaN              NaN
# 10257  More acceptable  More acceptable  More acceptable
# 10258  More acceptable    No difference    No difference
# 10259    No difference  More acceptable  More acceptable
#
#                  DCARS12_W99 DCARS13_a_W99 DCARS13_b_W99 DCARS13_c_W99  \
# 0                        NaN           NaN           NaN           NaN
# 1       Somewhat comfortable      Not sure        Oppose         Favor
# 2           Very comfortable         Favor      Not sure         Favor
# 3                        NaN           NaN           NaN           NaN
# 4                        NaN           NaN           NaN           NaN
# ...                      ...           ...           ...           ...
# 10255                    NaN           NaN           NaN           NaN
# 10256                    NaN           NaN           NaN           NaN
# 10257  Extremely comfortable         Favor         Favor         Favor
# 10258       Very comfortable         Favor        Oppose        Oppose
# 10259       Very comfortable      Not sure        Oppose      Not sure
#
#       DCARS13_d_W99
# 0               NaN
# 1             Favor
# 2             Favor
# 3               NaN
# 4               NaN
# ...             ...
# 10255           NaN
# 10256           NaN
# 10257         Favor
# 10258      Not sure
# 10259         Favor
#
# [10260 rows x 25 columns]

# %%
personinfo_df = selfcar_df.iloc[:,182:]
print(personinfo_df)
# Out:
#       F_RELCOM3CAT           F_METRO  F_CREGION         F_CDIVISION F_AGECAT  \
# 0           Medium      Metropolitan       West             Pacific      65+
# 1           Medium  Non-metropolitan    Midwest  East North Central      65+
# 2           Medium      Metropolitan  Northeast     Middle Atlantic    30-49
# 3           Medium      Metropolitan       West             Pacific    50-64
# 4           Medium      Metropolitan      South      South Atlantic      65+
# ...            ...               ...        ...                 ...      ...
# 10255          Low      Metropolitan  Northeast     Middle Atlantic    30-49
# 10256          Low      Metropolitan      South      South Atlantic    50-64
# 10257          Low      Metropolitan      South      South Atlantic    18-29
# 10258       Medium      Metropolitan    Midwest  East North Central      65+
# 10259         High      Metropolitan       West             Pacific    30-49
#
#       F_GENDER              F_EDUCCAT                       F_EDUCCAT2 F_HISP  \
# 0        A man      College graduate+  College graduate/some post grad     No
# 1        A man           Some College          Some college, no degree     No
# 2      A woman      College graduate+                     Postgraduate     No
# 3      A woman      College graduate+                     Postgraduate     No
# 4      A woman           Some College               Associate's degree     No
# ...        ...                    ...                              ...    ...
# 10255  A woman  H.S. graduate or less             High school graduate     No
# 10256    A man      College graduate+  College graduate/some post grad     No
# 10257  A woman           Some College               Associate's degree     No
# 10258    A man           Some College          Some college, no degree     No
# 10259  A woman      College graduate+  College graduate/some post grad     No
#
#       F_HISP_ORIGIN  ...       F_PARTYLN_FINAL F_PARTYSUM_FINAL  \
# 0               NaN  ...                   NaN     Rep/Lean Rep
# 1               NaN  ...                   NaN     Rep/Lean Rep
# 2               NaN  ...                   NaN     Dem/Lean Dem
# 3               NaN  ...                   NaN     Rep/Lean Rep
# 4               NaN  ...  The Republican Party     Rep/Lean Rep
# ...             ...  ...                   ...              ...
# 10255           NaN  ...  The Republican Party     Rep/Lean Rep
# 10256           NaN  ...                   NaN     Dem/Lean Dem
# 10257           NaN  ...  The Democratic Party     Dem/Lean Dem
# 10258           NaN  ...                   NaN     Rep/Lean Rep
# 10259           NaN  ...  The Republican Party     Rep/Lean Rep
#
#                  F_PARTYSUMIDEO_FINAL                    F_INC_SDT1  \
# 0               Conservative Rep/Lean  $50,000 to less than $60,000
# 1           Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 2      Moderate/Conservative Dem/Lean              $100,000 or more
# 3               Conservative Rep/Lean              $100,000 or more
# 4               Conservative Rep/Lean  $30,000 to less than $40,000
# ...                               ...                           ...
# 10255       Moderate/Liberal Rep/Lean             Less than $30,000
# 10256                Liberal Dem/Lean              $100,000 or more
# 10257                Liberal Dem/Lean             Less than $30,000
# 10258       Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 10259           Conservative Rep/Lean              $100,000 or more
#
#                                                    F_REG             F_IDEO  \
# 0      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1      You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2      You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3      You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# ...                                                  ...                ...
# 10255  You are NOT registered to vote at your current...           Moderate
# 10256  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10257  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10258  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 10259  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
#
#                  F_INTFREQ F_VOLSUM    F_INC_TIER2 WEIGHT_W99
# 0      Several times a day       No  Middle income   0.206396
# 1      Several times a day      Yes  Middle income   0.315090
# 2      Several times a day       No   Upper income   0.829579
# 3      Several times a day      Yes   Upper income   0.337527
# 4               Less often       No   Lower income   1.210606
# ...                    ...      ...            ...        ...
# 10255    Almost constantly       No   Lower income   0.425901
# 10256  Several times a day      Yes   Upper income   0.157638
# 10257    Almost constantly      Yes   Lower income   0.282079
# 10258  Several times a day       No  Middle income   0.441525
# 10259  Several times a day      Yes   Upper income   0.908670
#
# [10260 rows x 33 columns]

# %%
drive_selfcar_df = pd.concat([intro_df, selfcar_columns, personinfo_df], axis=1)
drive_selfcar_df.head()
# Out:
#      QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99 LANG_W99  \
# 0  100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC  English
# 1  100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone  English
# 2  100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone  English
# 3  100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC  English
# 4  100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC  English
#
#   FORM_W99    XTABLET_W99 DCARS1_W99             DCARS2_W99  \
# 0   Form 2  Non-tablet HH        NaN                    NaN
# 1   Form 1  Non-tablet HH   A little               Not sure
# 2   Form 1  Non-tablet HH   A little  Good idea for society
# 3   Form 2  Non-tablet HH        NaN                    NaN
# 4   Form 2  Non-tablet HH        NaN                    NaN
#
#           DCARS3_W99  ...       F_PARTYLN_FINAL F_PARTYSUM_FINAL  \
# 0                NaN  ...                   NaN     Rep/Lean Rep
# 1  Probably NOT want  ...                   NaN     Rep/Lean Rep
# 2      Probably want  ...                   NaN     Dem/Lean Dem
# 3                NaN  ...                   NaN     Rep/Lean Rep
# 4                NaN  ...  The Republican Party     Rep/Lean Rep
#
#              F_PARTYSUMIDEO_FINAL                    F_INC_SDT1  \
# 0           Conservative Rep/Lean  $50,000 to less than $60,000
# 1       Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 2  Moderate/Conservative Dem/Lean              $100,000 or more
# 3           Conservative Rep/Lean              $100,000 or more
# 4           Conservative Rep/Lean  $30,000 to less than $40,000
#
#                                                F_REG             F_IDEO  \
# 0  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4  You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
#
#              F_INTFREQ F_VOLSUM    F_INC_TIER2 WEIGHT_W99
# 0  Several times a day       No  Middle income   0.206396
# 1  Several times a day      Yes  Middle income   0.315090
# 2  Several times a day       No   Upper income   0.829579
# 3  Several times a day      Yes   Upper income   0.337527
# 4           Less often       No   Lower income   1.210606
#
# [5 rows x 65 columns]

# %%
drive_selfcar_df = drive_selfcar_df.rename(columns={'F_METRO': 'Metropolitan_Area',
                                                    'F_RELCOM3CAT': 'Relative_Commercial',
                                                    'F_CREGION': 'Region,',
                                                    'F_CDIVISION': 'Demographic_Region',
                                                    'F_AGECAT': 'Age',
                                                    'F_GENDER': 'Gender',
                                                    'F_EDUCCAT': 'Education',
                                                    'F_EDUCCAT2': 'Education_Degree',
                                                    'F_HISP': 'Hispanic',
                                                    'F_HISP_ORIGIN': 'Hispanic_Origin',
                                                    'F_YEARSINUS': 'Years_in_US',
                                                    'F_RACECMB': 'Race',
                                                    'F_RACETHNMOD': 'Ethnicity',
                                                    'F_CITIZEN': 'Citizen',
                                                    'F_BIRTHPLACE': 'Birthplace',
                                                    'F_MARITAL': 'Marital_Status',
                                                    'F_RELIG': 'Religion',
                                                    'F_BORN': 'Birth_Religion',
                                                    'F_RELIGCAT1': 'Religion_Category',
                                                    'F_ATTEND': 'Religion_Attend_Place',
                                                    'F_RELIMP': 'Religion_Importance',
                                                    'F_PRAY': 'Religion_Prayer',
                                                    'F_PARTY_FINAL':'People_Political',
                                                    'F_PARTYLN_FINAL':'People_Political_Party',
                                                    'F_PARTYSUM_FINAL':'People_Political_Type',
                                                    'F_PARTYSUMIDEO_FINAL': 'People_Political_Type_Category',
                                                    'F_INC_SDT1': 'Income_Level',
                                                    'F_REG': 'Vote_Registered_Adress',
                                                    'F_IDEO': 'Ideology',
                                                    'F_INTFREQ': 'Interaction_Frequency',
                                                    'F_VOLSUM': 'Volume_Sum',
                                                    'F_INC_TIER2':'Income_Class',
                                                    'WEIGHT_W99': 'Weight_99_Percent'})
drive_selfcar_df
# Out:
#                QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99  \
# 0            100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC
# 1            100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone
# 2            100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone
# 3            100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC
# 4            100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC
# ...             ...                 ...                 ...             ...
# 10255  202101013246 2021-11-02 15:06:47 2021-11-02 15:21:18      Smartphone
# 10256  202101013292 2021-11-02 12:18:58 2021-11-02 12:32:49      Smartphone
# 10257  202101013344 2021-11-04 16:30:29 2021-11-06 11:08:56      Smartphone
# 10258  202101013446 2021-11-06 15:22:13 2021-11-06 16:10:36       Laptop/PC
# 10259  202101013477 2021-11-02 23:46:38 2021-11-02 23:56:21      Smartphone
#
#       LANG_W99 FORM_W99    XTABLET_W99 DCARS1_W99             DCARS2_W99  \
# 0      English   Form 2  Non-tablet HH        NaN                    NaN
# 1      English   Form 1  Non-tablet HH   A little               Not sure
# 2      English   Form 1  Non-tablet HH   A little  Good idea for society
# 3      English   Form 2  Non-tablet HH        NaN                    NaN
# 4      English   Form 2  Non-tablet HH        NaN                    NaN
# ...        ...      ...            ...        ...                    ...
# 10255  English   Form 2  Non-tablet HH        NaN                    NaN
# 10256  English   Form 2  Non-tablet HH        NaN                    NaN
# 10257  English   Form 1  Non-tablet HH      A lot  Good idea for society
# 10258  English   Form 1  Non-tablet HH   A little  Good idea for society
# 10259  English   Form 1  Non-tablet HH   A little               Not sure
#
#               DCARS3_W99  ... People_Political_Party People_Political_Type  \
# 0                    NaN  ...                    NaN          Rep/Lean Rep
# 1      Probably NOT want  ...                    NaN          Rep/Lean Rep
# 2          Probably want  ...                    NaN          Dem/Lean Dem
# 3                    NaN  ...                    NaN          Rep/Lean Rep
# 4                    NaN  ...   The Republican Party          Rep/Lean Rep
# ...                  ...  ...                    ...                   ...
# 10255                NaN  ...   The Republican Party          Rep/Lean Rep
# 10256                NaN  ...                    NaN          Dem/Lean Dem
# 10257    Definitely want  ...   The Democratic Party          Dem/Lean Dem
# 10258    Definitely want  ...                    NaN          Rep/Lean Rep
# 10259  Probably NOT want  ...   The Republican Party          Rep/Lean Rep
#
#        People_Political_Type_Category                  Income_Level  \
# 0               Conservative Rep/Lean  $50,000 to less than $60,000
# 1           Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 2      Moderate/Conservative Dem/Lean              $100,000 or more
# 3               Conservative Rep/Lean              $100,000 or more
# 4               Conservative Rep/Lean  $30,000 to less than $40,000
# ...                               ...                           ...
# 10255       Moderate/Liberal Rep/Lean             Less than $30,000
# 10256                Liberal Dem/Lean              $100,000 or more
# 10257                Liberal Dem/Lean             Less than $30,000
# 10258       Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 10259           Conservative Rep/Lean              $100,000 or more
#
#                                   Vote_Registered_Adress           Ideology  \
# 0      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1      You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2      You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3      You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# ...                                                  ...                ...
# 10255  You are NOT registered to vote at your current...           Moderate
# 10256  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10257  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10258  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 10259  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
#
#       Interaction_Frequency Volume_Sum   Income_Class Weight_99_Percent
# 0       Several times a day         No  Middle income          0.206396
# 1       Several times a day        Yes  Middle income          0.315090
# 2       Several times a day         No   Upper income          0.829579
# 3       Several times a day        Yes   Upper income          0.337527
# 4                Less often         No   Lower income          1.210606
# ...                     ...        ...            ...               ...
# 10255     Almost constantly         No   Lower income          0.425901
# 10256   Several times a day        Yes   Upper income          0.157638
# 10257     Almost constantly        Yes   Lower income          0.282079
# 10258   Several times a day         No  Middle income          0.441525
# 10259   Several times a day        Yes   Upper income          0.908670
#
# [10260 rows x 65 columns]

# %%
drive_selfcar_df = drive_selfcar_df.rename(columns={'DCARS1_W99' : 'Read_about_SelfDrive_Car',
                                                    'DCARS2_W99' : 'Widespread_use_SelfDrive_Car',
                                                    'DCARS3_W99' : 'Choice_drive_SelfDrive_Car',
                                                    'DCARS4_a_W99' : 'Passenger_SelfDrive_Car_CaseA',
                                                    'DCARS4_b_W99' : 'Passenger_SelfDrive_Car_CaseB',
                                                    'DCARS4_c_W99' : 'Passenger_SelfDrive_Car_CaseC',
                                                    'DCARS4_d_W99' : 'Passenger_SelfDrive_Car_CaseD',
                                                    'DCARS5_W99' : 'Income_class_SelfDrive_Car',
                                                    'DCARS6_W99' : 'Accident_SelfDrive_Car',
                                                    'DCARS7_W99' : 'UnnAccident_SelfDrive_Car',
                                                    'DCARS8_a_W99' : 'Group_role_SelfDrive_Car_CaseA',
                                                    'DCARS8_b_W99' : 'Group_role_SelfDrive_Car_CaseB',
                                                    'DCARS8_c_W99' : 'Group_role_SelfDrive_Car_CaseC',
                                                    'DCARS8_d_W99' : 'Group_role_SelfDrive_Car_CaseD',
                                                    'DCARS9_W99' : 'Concern_SelfDrive_Car',
                                                    'DCARS10_W99' : 'Safety_SelfDrive_Car',
                                                    'DCARS11_a_W99' : 'Accpt_circumstances_SelfDrive_Car_CaseA',
                                                    'DCARS11_b_W99' : 'Accpt_circumstances_SelfDrive_Car_CaseB',
                                                    'DCARS11_c_W99' : 'Accpt_circumstances_SelfDrive_Car_CaseC',
                                                    'DCARS11_d_W99' : 'Accpt_circumstances_SelfDrive_Car_CaseD',
                                                    'DCARS12_W99' : 'Share_road_SelfDriveCar',
                                                    'DCARS13_a_W99' : 'Purpose_SelfDriveCar_CaseA',
                                                    'DCARS13_b_W99' : 'Purpose_SelfDriveCar_CaseB',
                                                    'DCARS13_c_W99' : 'Purpose_SelfDriveCar_CaseC',
                                                    'DCARS13_d_W99' : 'Purpose_SelfDriveCar_CaseD'
})

drive_selfcar_df
# Out:
#                QKEY INTERVIEW_START_W99   INTERVIEW_END_W99 DEVICE_TYPE_W99  \
# 0            100260 2021-11-03 14:25:27 2021-11-03 14:45:34       Laptop/PC
# 1            100314 2021-11-04 12:35:35 2021-11-04 12:55:29      Smartphone
# 2            100363 2021-11-03 20:23:43 2021-11-03 20:36:24      Smartphone
# 3            100598 2021-11-02 13:01:05 2021-11-04 12:37:42       Laptop/PC
# 4            100637 2021-11-02 12:32:58 2021-11-02 12:46:23       Laptop/PC
# ...             ...                 ...                 ...             ...
# 10255  202101013246 2021-11-02 15:06:47 2021-11-02 15:21:18      Smartphone
# 10256  202101013292 2021-11-02 12:18:58 2021-11-02 12:32:49      Smartphone
# 10257  202101013344 2021-11-04 16:30:29 2021-11-06 11:08:56      Smartphone
# 10258  202101013446 2021-11-06 15:22:13 2021-11-06 16:10:36       Laptop/PC
# 10259  202101013477 2021-11-02 23:46:38 2021-11-02 23:56:21      Smartphone
#
#       LANG_W99 FORM_W99    XTABLET_W99 Read_about_SelfDrive_Car  \
# 0      English   Form 2  Non-tablet HH                      NaN
# 1      English   Form 1  Non-tablet HH                 A little
# 2      English   Form 1  Non-tablet HH                 A little
# 3      English   Form 2  Non-tablet HH                      NaN
# 4      English   Form 2  Non-tablet HH                      NaN
# ...        ...      ...            ...                      ...
# 10255  English   Form 2  Non-tablet HH                      NaN
# 10256  English   Form 2  Non-tablet HH                      NaN
# 10257  English   Form 1  Non-tablet HH                    A lot
# 10258  English   Form 1  Non-tablet HH                 A little
# 10259  English   Form 1  Non-tablet HH                 A little
#
#       Widespread_use_SelfDrive_Car Choice_drive_SelfDrive_Car  ...  \
# 0                              NaN                        NaN  ...
# 1                         Not sure          Probably NOT want  ...
# 2            Good idea for society              Probably want  ...
# 3                              NaN                        NaN  ...
# 4                              NaN                        NaN  ...
# ...                            ...                        ...  ...
# 10255                          NaN                        NaN  ...
# 10256                          NaN                        NaN  ...
# 10257        Good idea for society            Definitely want  ...
# 10258        Good idea for society            Definitely want  ...
# 10259                     Not sure          Probably NOT want  ...
#
#       People_Political_Party People_Political_Type  \
# 0                        NaN          Rep/Lean Rep
# 1                        NaN          Rep/Lean Rep
# 2                        NaN          Dem/Lean Dem
# 3                        NaN          Rep/Lean Rep
# 4       The Republican Party          Rep/Lean Rep
# ...                      ...                   ...
# 10255   The Republican Party          Rep/Lean Rep
# 10256                    NaN          Dem/Lean Dem
# 10257   The Democratic Party          Dem/Lean Dem
# 10258                    NaN          Rep/Lean Rep
# 10259   The Republican Party          Rep/Lean Rep
#
#        People_Political_Type_Category                  Income_Level  \
# 0               Conservative Rep/Lean  $50,000 to less than $60,000
# 1           Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 2      Moderate/Conservative Dem/Lean              $100,000 or more
# 3               Conservative Rep/Lean              $100,000 or more
# 4               Conservative Rep/Lean  $30,000 to less than $40,000
# ...                               ...                           ...
# 10255       Moderate/Liberal Rep/Lean             Less than $30,000
# 10256                Liberal Dem/Lean              $100,000 or more
# 10257                Liberal Dem/Lean             Less than $30,000
# 10258       Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 10259           Conservative Rep/Lean              $100,000 or more
#
#                                   Vote_Registered_Adress           Ideology  \
# 0      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1      You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2      You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3      You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# ...                                                  ...                ...
# 10255  You are NOT registered to vote at your current...           Moderate
# 10256  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10257  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10258  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 10259  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
#
#       Interaction_Frequency Volume_Sum   Income_Class Weight_99_Percent
# 0       Several times a day         No  Middle income          0.206396
# 1       Several times a day        Yes  Middle income          0.315090
# 2       Several times a day         No   Upper income          0.829579
# 3       Several times a day        Yes   Upper income          0.337527
# 4                Less often         No   Lower income          1.210606
# ...                     ...        ...            ...               ...
# 10255     Almost constantly         No   Lower income          0.425901
# 10256   Several times a day        Yes   Upper income          0.157638
# 10257     Almost constantly        Yes   Lower income          0.282079
# 10258   Several times a day         No  Middle income          0.441525
# 10259   Several times a day        Yes   Upper income          0.908670
#
# [10260 rows x 65 columns]

# %%
drive_selfcar_df = drive_selfcar_df.rename(columns={ 'QKEY' : 'Question_key',
                                                    'INTERVIEW_START_W99': 'Interview_start_time',
                                                    'INTERVIEW_END_W99': 'Interview_end_time',
                                                    'DEVICE_TYPE_W99' : 'Device_Type',
                                                    'LANG_W99' : 'Language',
                                                    'FORM_W99' : 'Form_No',
                                                    'XTABLET_W99': 'Tablet_category'
})

drive_selfcar_df
# Out:
#        Question_key Interview_start_time  Interview_end_time Device_Type  \
# 0            100260  2021-11-03 14:25:27 2021-11-03 14:45:34   Laptop/PC
# 1            100314  2021-11-04 12:35:35 2021-11-04 12:55:29  Smartphone
# 2            100363  2021-11-03 20:23:43 2021-11-03 20:36:24  Smartphone
# 3            100598  2021-11-02 13:01:05 2021-11-04 12:37:42   Laptop/PC
# 4            100637  2021-11-02 12:32:58 2021-11-02 12:46:23   Laptop/PC
# ...             ...                  ...                 ...         ...
# 10255  202101013246  2021-11-02 15:06:47 2021-11-02 15:21:18  Smartphone
# 10256  202101013292  2021-11-02 12:18:58 2021-11-02 12:32:49  Smartphone
# 10257  202101013344  2021-11-04 16:30:29 2021-11-06 11:08:56  Smartphone
# 10258  202101013446  2021-11-06 15:22:13 2021-11-06 16:10:36   Laptop/PC
# 10259  202101013477  2021-11-02 23:46:38 2021-11-02 23:56:21  Smartphone
#
#       Language Form_No Tablet_category Read_about_SelfDrive_Car  \
# 0      English  Form 2   Non-tablet HH                      NaN
# 1      English  Form 1   Non-tablet HH                 A little
# 2      English  Form 1   Non-tablet HH                 A little
# 3      English  Form 2   Non-tablet HH                      NaN
# 4      English  Form 2   Non-tablet HH                      NaN
# ...        ...     ...             ...                      ...
# 10255  English  Form 2   Non-tablet HH                      NaN
# 10256  English  Form 2   Non-tablet HH                      NaN
# 10257  English  Form 1   Non-tablet HH                    A lot
# 10258  English  Form 1   Non-tablet HH                 A little
# 10259  English  Form 1   Non-tablet HH                 A little
#
#       Widespread_use_SelfDrive_Car Choice_drive_SelfDrive_Car  ...  \
# 0                              NaN                        NaN  ...
# 1                         Not sure          Probably NOT want  ...
# 2            Good idea for society              Probably want  ...
# 3                              NaN                        NaN  ...
# 4                              NaN                        NaN  ...
# ...                            ...                        ...  ...
# 10255                          NaN                        NaN  ...
# 10256                          NaN                        NaN  ...
# 10257        Good idea for society            Definitely want  ...
# 10258        Good idea for society            Definitely want  ...
# 10259                     Not sure          Probably NOT want  ...
#
#       People_Political_Party People_Political_Type  \
# 0                        NaN          Rep/Lean Rep
# 1                        NaN          Rep/Lean Rep
# 2                        NaN          Dem/Lean Dem
# 3                        NaN          Rep/Lean Rep
# 4       The Republican Party          Rep/Lean Rep
# ...                      ...                   ...
# 10255   The Republican Party          Rep/Lean Rep
# 10256                    NaN          Dem/Lean Dem
# 10257   The Democratic Party          Dem/Lean Dem
# 10258                    NaN          Rep/Lean Rep
# 10259   The Republican Party          Rep/Lean Rep
#
#        People_Political_Type_Category                  Income_Level  \
# 0               Conservative Rep/Lean  $50,000 to less than $60,000
# 1           Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 2      Moderate/Conservative Dem/Lean              $100,000 or more
# 3               Conservative Rep/Lean              $100,000 or more
# 4               Conservative Rep/Lean  $30,000 to less than $40,000
# ...                               ...                           ...
# 10255       Moderate/Liberal Rep/Lean             Less than $30,000
# 10256                Liberal Dem/Lean              $100,000 or more
# 10257                Liberal Dem/Lean             Less than $30,000
# 10258       Moderate/Liberal Rep/Lean  $40,000 to less than $50,000
# 10259           Conservative Rep/Lean              $100,000 or more
#
#                                   Vote_Registered_Adress           Ideology  \
# 0      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# 1      You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 2      You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 3      You are ABSOLUTELY CERTAIN that you are regist...       Conservative
# 4      You are ABSOLUTELY CERTAIN that you are regist...  Very conservative
# ...                                                  ...                ...
# 10255  You are NOT registered to vote at your current...           Moderate
# 10256  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10257  You are ABSOLUTELY CERTAIN that you are regist...            Liberal
# 10258  You are ABSOLUTELY CERTAIN that you are regist...           Moderate
# 10259  You are ABSOLUTELY CERTAIN that you are regist...       Conservative
#
#       Interaction_Frequency Volume_Sum   Income_Class Weight_99_Percent
# 0       Several times a day         No  Middle income          0.206396
# 1       Several times a day        Yes  Middle income          0.315090
# 2       Several times a day         No   Upper income          0.829579
# 3       Several times a day        Yes   Upper income          0.337527
# 4                Less often         No   Lower income          1.210606
# ...                     ...        ...            ...               ...
# 10255     Almost constantly         No   Lower income          0.425901
# 10256   Several times a day        Yes   Upper income          0.157638
# 10257     Almost constantly        Yes   Lower income          0.282079
# 10258   Several times a day         No  Middle income          0.441525
# 10259   Several times a day        Yes   Upper income          0.908670
#
# [10260 rows x 65 columns]

# %%
excel_file = 'MMAI_Fundamental_Assignment.xlsx'
drive_selfcar_df.to_excel(excel_file)

print(f'Excel file: {excel_file}')
# Out:
# Excel file: MMAI_Fundamental_Assignment.xlsx

# %%
drive_selfcar_df.isna().sum() > 0
# Out:
# Question_key             False
# Interview_start_time     False
# Interview_end_time       False
# Device_Type              False
# Language                 False
#                          ...
# Ideology                 False
# Interaction_Frequency     True
# Volume_Sum               False
# Income_Class             False
# Weight_99_Percent        False
# Length: 65, dtype: bool

# %%
drive_selfcar_df.columns[drive_selfcar_df.isna().any()]
# Out:
# Index(['Read_about_SelfDrive_Car', 'Widespread_use_SelfDrive_Car',
#        'Choice_drive_SelfDrive_Car', 'Passenger_SelfDrive_Car_CaseA',
#        'Passenger_SelfDrive_Car_CaseB', 'Passenger_SelfDrive_Car_CaseC',
#        'Passenger_SelfDrive_Car_CaseD', 'Income_class_SelfDrive_Car',
#        'Accident_SelfDrive_Car', 'UnnAccident_SelfDrive_Car',
#        'Group_role_SelfDrive_Car_CaseA', 'Group_role_SelfDrive_Car_CaseB',
#        'Group_role_SelfDrive_Car_CaseC', 'Group_role_SelfDrive_Car_CaseD',
#        'Concern_SelfDrive_Car', 'Safety_SelfDrive_Car',
#        'Accpt_circumstances_SelfDrive_Car_CaseA',
#        'Accpt_circumstances_SelfDrive_Car_CaseB',
#        'Accpt_circumstances_SelfDrive_Car_CaseC',
#        'Accpt_circumstances_SelfDrive_Car_CaseD', 'Share_road_SelfDriveCar',
#        'Purpose_SelfDriveCar_CaseA', 'Purpose_SelfDriveCar_CaseB',
#        'Purpose_SelfDriveCar_CaseC', 'Purpose_SelfDriveCar_CaseD',
#        'Hispanic_Origin', 'Birth_Religion', 'People_Political_Party',
#        'Vote_Registered_Adress', 'Interaction_Frequency'],
#       dtype='object')

# %%
drive_selfcar_df['Weight_99_Percent'].plot()

# %%
drive_selfcar_df['Income_Level'].unique()
# Out:
# array(['$50,000 to less than $60,000', '$40,000 to less than $50,000',
#        '$100,000 or more', '$30,000 to less than $40,000',
#        'Less than $30,000', '$70,000 to less than $80,000', 'Refused',
#        '$80,000 to less than $90,000', '$90,000 to less than $100,000',
#        '$60,000 to less than $70,000'], dtype=object)

# %%
#drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(lambda x: '50000 - 60000' if x == '$50,000 to less than $60,000')

drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '50000 - 60000' if str(x).lower() == '$50,000 to less than $60,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '40000 - 50000' if str(x).lower() == '$40,000 to less than $50,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '100000' if str(x).lower() == '$100,000 or more'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '30000 - 40000' if str(x).lower() == '$30,000 to less than $40,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '30000' if str(x).lower() == 'Less than $30,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '70000 - 80000' if str(x).lower() == '$70,000 to less than $80,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '80000 - 90000' if str(x).lower() == '$80,000 to less than $90,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '90000 - 100000' if str(x).lower() == '$90,000 to less than $100,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: '60000 - 70000' if str(x).lower() == '$60,000 to less than $70,000'.lower() else x)
drive_selfcar_df['Income_Level'] = drive_selfcar_df['Income_Level'].apply(
    lambda x: 0 if str(x).lower() == 'Refused'.lower() else x)

drive_selfcar_df['Income_Level'].unique()
# Out:
# array(['50000 - 60000', '40000 - 50000', '100000', '30000 - 40000',
#        '30000', '70000 - 80000', 0, '80000 - 90000', '90000 - 100000',
#        '60000 - 70000'], dtype=object)

# %%
drive_selfcar_df.columns
# Out:
# Index(['Question_key', 'Interview_start_time', 'Interview_end_time',
#        'Device_Type', 'Language', 'Form_No', 'Tablet_category',
#        'Read_about_SelfDrive_Car', 'Widespread_use_SelfDrive_Car',
#        'Choice_drive_SelfDrive_Car', 'Passenger_SelfDrive_Car_CaseA',
#        'Passenger_SelfDrive_Car_CaseB', 'Passenger_SelfDrive_Car_CaseC',
#        'Passenger_SelfDrive_Car_CaseD', 'Income_class_SelfDrive_Car',
#        'Accident_SelfDrive_Car', 'UnnAccident_SelfDrive_Car',
#        'Group_role_SelfDrive_Car_CaseA', 'Group_role_SelfDrive_Car_CaseB',
#        'Group_role_SelfDrive_Car_CaseC', 'Group_role_SelfDrive_Car_CaseD',
#        'Concern_SelfDrive_Car', 'Safety_SelfDrive_Car',
#        'Accpt_circumstances_SelfDrive_Car_CaseA',
#        'Accpt_circumstances_SelfDrive_Car_CaseB',
#        'Accpt_circumstances_SelfDrive_Car_CaseC',
#        'Accpt_circumstances_SelfDrive_Car_CaseD', 'Share_road_SelfDriveCar',
#        'Purpose_SelfDriveCar_CaseA', 'Purpose_SelfDriveCar_CaseB',
#        'Purpose_SelfDriveCar_CaseC', 'Purpose_SelfDriveCar_CaseD',
#        'Relative_Commercial', 'Metropolitan_Area', 'Region,',
#        'Demographic_Region', 'Age', 'Gender', 'Education', 'Education_Degree',
#        'Hispanic', 'Hispanic_Origin', 'Years_in_US', 'Race', 'Ethnicity',
#        'Citizen', 'Birthplace', 'Marital_Status', 'Religion', 'Birth_Religion',
#        'Religion_Category', 'Religion_Attend_Place', 'Religion_Importance',
#        'Religion_Prayer', 'People_Political', 'People_Political_Party',
#        'People_Political_Type', 'People_Political_Type_Category',
#        'Income_Level', 'Vote_Registered_Adress', 'Ideology',
#        'Interaction_Frequency', 'Volume_Sum', 'Income_Class',
#        'Weight_99_Percent'],
#       dtype='object')

# %%
drive_selfcar_df = drive_selfcar_df.drop(['Form_No', 'Tablet_category', 'Hispanic', 'Hispanic_Origin', 'Religion', 'Birth_Religion',
       'Religion_Category', 'Religion_Attend_Place', 'Religion_Importance',
       'Religion_Prayer', 'People_Political', 'People_Political_Party',
       'People_Political_Type', 'People_Political_Type_Category'], axis=1)

drive_selfcar_df
# Out:
#        Question_key Interview_start_time  Interview_end_time Device_Type  \
# 0            100260  2021-11-03 14:25:27 2021-11-03 14:45:34   Laptop/PC
# 1            100314  2021-11-04 12:35:35 2021-11-04 12:55:29  Smartphone
# 2            100363  2021-11-03 20:23:43 2021-11-03 20:36:24  Smartphone
# 3            100598  2021-11-02 13:01:05 2021-11-04 12:37:42   Laptop/PC
# 4            100637  2021-11-02 12:32:58 2021-11-02 12:46:23   Laptop/PC
# ...             ...                  ...                 ...         ...
# 10255  202101013246  2021-11-02 15:06:47 2021-11-02 15:21:18  Smartphone
# 10256  202101013292  2021-11-02 12:18:58 2021-11-02 12:32:49  Smartphone
# 10257  202101013344  2021-11-04 16:30:29 2021-11-06 11:08:56  Smartphone
# 10258  202101013446  2021-11-06 15:22:13 2021-11-06 16:10:36   Laptop/PC
# 10259  202101013477  2021-11-02 23:46:38 2021-11-02 23:56:21  Smartphone
#
#       Language Read_about_SelfDrive_Car Widespread_use_SelfDrive_Car  \
# 0      English                      NaN                          NaN
# 1      English                 A little                     Not sure
# 2      English                 A little        Good idea for society
# 3      English                      NaN                          NaN
# 4      English                      NaN                          NaN
# ...        ...                      ...                          ...
# 10255  English                      NaN                          NaN
# 10256  English                      NaN                          NaN
# 10257  English                    A lot        Good idea for society
# 10258  English                 A little        Good idea for society
# 10259  English                 A little                     Not sure
#
#       Choice_drive_SelfDrive_Car Passenger_SelfDrive_Car_CaseA  \
# 0                            NaN                           NaN
# 1              Probably NOT want         Probably would happen
# 2                  Probably want       Definitely would happen
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ...                          ...                           ...
# 10255                        NaN                           NaN
# 10256                        NaN                           NaN
# 10257            Definitely want       Definitely would happen
# 10258            Definitely want       Definitely would happen
# 10259          Probably NOT want     Probably would NOT happen
#
#       Passenger_SelfDrive_Car_CaseB  ... Citizen  \
# 0                               NaN  ...     Yes
# 1             Probably would happen  ...     Yes
# 2           Definitely would happen  ...     Yes
# 3                               NaN  ...     Yes
# 4                               NaN  ...     Yes
# ...                             ...  ...     ...
# 10255                           NaN  ...     Yes
# 10256                           NaN  ...     Yes
# 10257       Definitely would happen  ...     Yes
# 10258         Probably would happen  ...     Yes
# 10259     Probably would NOT happen  ...     Yes
#
#                                    Birthplace         Marital_Status  \
# 0      U.S. – 50 states, District of Columbia     Never been married
# 1      U.S. – 50 states, District of Columbia               Divorced
# 2      U.S. – 50 states, District of Columbia                Married
# 3      U.S. – 50 states, District of Columbia                Married
# 4      U.S. – 50 states, District of Columbia                Married
# ...                                       ...                    ...
# 10255  U.S. – 50 states, District of Columbia                Married
# 10256  U.S. – 50 states, District of Columbia                Married
# 10257  U.S. – 50 states, District of Columbia  Living with a partner
# 10258  U.S. – 50 states, District of Columbia                Married
# 10259  U.S. – 50 states, District of Columbia                Married
#
#         Income_Level                             Vote_Registered_Adress  \
# 0      50000 - 60000  You are ABSOLUTELY CERTAIN that you are regist...
# 1      40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 2             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 3             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 4      30000 - 40000  You are ABSOLUTELY CERTAIN that you are regist...
# ...              ...                                                ...
# 10255          30000  You are NOT registered to vote at your current...
# 10256         100000  You are ABSOLUTELY CERTAIN that you are regist...
# 10257          30000  You are ABSOLUTELY CERTAIN that you are regist...
# 10258  40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 10259         100000  You are ABSOLUTELY CERTAIN that you are regist...
#
#                 Ideology Interaction_Frequency Volume_Sum   Income_Class  \
# 0      Very conservative   Several times a day         No  Middle income
# 1                Liberal   Several times a day        Yes  Middle income
# 2               Moderate   Several times a day         No   Upper income
# 3           Conservative   Several times a day        Yes   Upper income
# 4      Very conservative            Less often         No   Lower income
# ...                  ...                   ...        ...            ...
# 10255           Moderate     Almost constantly         No   Lower income
# 10256            Liberal   Several times a day        Yes   Upper income
# 10257            Liberal     Almost constantly        Yes   Lower income
# 10258           Moderate   Several times a day         No  Middle income
# 10259       Conservative   Several times a day        Yes   Upper income
#
#       Weight_99_Percent
# 0              0.206396
# 1              0.315090
# 2              0.829579
# 3              0.337527
# 4              1.210606
# ...                 ...
# 10255          0.425901
# 10256          0.157638
# 10257          0.282079
# 10258          0.441525
# 10259          0.908670
#
# [10260 rows x 51 columns]

# %%
drive_selfcar_df.dropna(inplace = True)

# %%
drive_selfcar_df
# Out:
#        Question_key Interview_start_time  Interview_end_time Device_Type  \
# 1            100314  2021-11-04 12:35:35 2021-11-04 12:55:29  Smartphone
# 2            100363  2021-11-03 20:23:43 2021-11-03 20:36:24  Smartphone
# 5            100803  2021-11-03 19:22:44 2021-11-03 19:41:04   Laptop/PC
# 6            101224  2021-11-03 18:18:21 2021-11-03 18:33:41  Smartphone
# 8            101485  2021-11-02 19:22:24 2021-11-02 19:35:23  Smartphone
# ...             ...                  ...                 ...         ...
# 10252  202101013187  2021-11-03 18:50:06 2021-11-03 19:02:32   Laptop/PC
# 10253  202101013227  2021-11-02 14:27:17 2021-11-02 15:01:43  Smartphone
# 10257  202101013344  2021-11-04 16:30:29 2021-11-06 11:08:56  Smartphone
# 10258  202101013446  2021-11-06 15:22:13 2021-11-06 16:10:36   Laptop/PC
# 10259  202101013477  2021-11-02 23:46:38 2021-11-02 23:56:21  Smartphone
#
#       Language Read_about_SelfDrive_Car Widespread_use_SelfDrive_Car  \
# 1      English                 A little                     Not sure
# 2      English                 A little        Good idea for society
# 5      English                 A little         Bad idea for society
# 6      English                 A little         Bad idea for society
# 8      English                 A little         Bad idea for society
# ...        ...                      ...                          ...
# 10252  English                 A little         Bad idea for society
# 10253  English                    A lot                     Not sure
# 10257  English                    A lot        Good idea for society
# 10258  English                 A little        Good idea for society
# 10259  English                 A little                     Not sure
#
#       Choice_drive_SelfDrive_Car Passenger_SelfDrive_Car_CaseA  \
# 1              Probably NOT want         Probably would happen
# 2                  Probably want       Definitely would happen
# 5            Definitely NOT want     Probably would NOT happen
# 6              Probably NOT want     Probably would NOT happen
# 8              Probably NOT want     Probably would NOT happen
# ...                          ...                           ...
# 10252          Probably NOT want         Probably would happen
# 10253        Definitely NOT want         Probably would happen
# 10257            Definitely want       Definitely would happen
# 10258            Definitely want       Definitely would happen
# 10259          Probably NOT want     Probably would NOT happen
#
#       Passenger_SelfDrive_Car_CaseB  ... Citizen  \
# 1             Probably would happen  ...     Yes
# 2           Definitely would happen  ...     Yes
# 5           Definitely would happen  ...     Yes
# 6             Probably would happen  ...     Yes
# 8         Probably would NOT happen  ...     Yes
# ...                             ...  ...     ...
# 10252       Definitely would happen  ...     Yes
# 10253       Definitely would happen  ...     Yes
# 10257       Definitely would happen  ...     Yes
# 10258         Probably would happen  ...     Yes
# 10259     Probably would NOT happen  ...     Yes
#
#                                    Birthplace         Marital_Status  \
# 1      U.S. – 50 states, District of Columbia               Divorced
# 2      U.S. – 50 states, District of Columbia                Married
# 5      U.S. – 50 states, District of Columbia                Married
# 6      U.S. – 50 states, District of Columbia                Married
# 8      U.S. – 50 states, District of Columbia                Widowed
# ...                                       ...                    ...
# 10252                         Another country                Married
# 10253  U.S. – 50 states, District of Columbia                Married
# 10257  U.S. – 50 states, District of Columbia  Living with a partner
# 10258  U.S. – 50 states, District of Columbia                Married
# 10259  U.S. – 50 states, District of Columbia                Married
#
#         Income_Level                             Vote_Registered_Adress  \
# 1      40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 2             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 5             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 6      40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 8             100000  You are ABSOLUTELY CERTAIN that you are regist...
# ...              ...                                                ...
# 10252          30000  You are NOT registered to vote at your current...
# 10253  50000 - 60000  You are NOT registered to vote at your current...
# 10257          30000  You are ABSOLUTELY CERTAIN that you are regist...
# 10258  40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 10259         100000  You are ABSOLUTELY CERTAIN that you are regist...
#
#            Ideology Interaction_Frequency Volume_Sum   Income_Class  \
# 1           Liberal   Several times a day        Yes  Middle income
# 2          Moderate   Several times a day         No   Upper income
# 5      Conservative  Several times a week        Yes   Upper income
# 6      Conservative      About once a day        Yes  Middle income
# 8      Conservative     Almost constantly        Yes   Upper income
# ...             ...                   ...        ...            ...
# 10252      Moderate     Almost constantly        Yes   Lower income
# 10253       Refused  Several times a week         No  Middle income
# 10257       Liberal     Almost constantly        Yes   Lower income
# 10258      Moderate   Several times a day         No  Middle income
# 10259  Conservative   Several times a day        Yes   Upper income
#
#       Weight_99_Percent
# 1              0.315090
# 2              0.829579
# 5              0.302004
# 6              0.287719
# 8              0.276541
# ...                 ...
# 10252          1.230882
# 10253          8.524234
# 10257          0.282079
# 10258          0.441525
# 10259          0.908670
#
# [4876 rows x 51 columns]

# %%
drive_selfcar_df['Gender'].unique()
# Out:
# array(['A man', 'A woman', 'In some other way', 'Refused'], dtype=object)

# %%
drive_selfcar_df[drive_selfcar_df['Gender'] == 'Refused'].count()
# Out:
# Question_key                               11
# Interview_start_time                       11
# Interview_end_time                         11
# Device_Type                                11
# Language                                   11
# Read_about_SelfDrive_Car                   11
# Widespread_use_SelfDrive_Car               11
# Choice_drive_SelfDrive_Car                 11
# Passenger_SelfDrive_Car_CaseA              11
# Passenger_SelfDrive_Car_CaseB              11
# Passenger_SelfDrive_Car_CaseC              11
# Passenger_SelfDrive_Car_CaseD              11
# Income_class_SelfDrive_Car                 11
# Accident_SelfDrive_Car                     11
# UnnAccident_SelfDrive_Car                  11
# Group_role_SelfDrive_Car_CaseA             11
# Group_role_SelfDrive_Car_CaseB             11
# Group_role_SelfDrive_Car_CaseC             11
# Group_role_SelfDrive_Car_CaseD             11
# Concern_SelfDrive_Car                      11
# Safety_SelfDrive_Car                       11
# Accpt_circumstances_SelfDrive_Car_CaseA    11
# Accpt_circumstances_SelfDrive_Car_CaseB    11
# Accpt_circumstances_SelfDrive_Car_CaseC    11
# Accpt_circumstances_SelfDrive_Car_CaseD    11
# Share_road_SelfDriveCar                    11
# Purpose_SelfDriveCar_CaseA                 11
# Purpose_SelfDriveCar_CaseB                 11
# Purpose_SelfDriveCar_CaseC                 11
# Purpose_SelfDriveCar_CaseD                 11
# Relative_Commercial                        11
# Metropolitan_Area                          11
# Region,                                    11
# Demographic_Region                         11
# Age                                        11
# Gender                                     11
# Education                                  11
# Education_Degree                           11
# Years_in_US                                11
# Race                                       11
# Ethnicity                                  11
# Citizen                                    11
# Birthplace                                 11
# Marital_Status                             11
# Income_Level                               11
# Vote_Registered_Adress                     11
# Ideology                                   11
# Interaction_Frequency                      11
# Volume_Sum                                 11
# Income_Class                               11
# Weight_99_Percent                          11
# dtype: int64

# %%
#'A man', 'A woman', 'In some other way', 'Refused'

drive_selfcar_df['Gender'] = drive_selfcar_df['Gender'].apply(
    lambda x: 'Man' if str(x).lower() == 'A man'.lower() else x)
drive_selfcar_df['Gender'] = drive_selfcar_df['Gender'].apply(
    lambda x: 'Woman' if str(x).lower() == 'A woman'.lower() else x)
drive_selfcar_df['Gender'] = drive_selfcar_df['Gender'].apply(
    lambda x: 'Other' if str(x).lower() == 'In some other way'.lower() else x)
drive_selfcar_df['Gender'] = drive_selfcar_df['Gender'].apply(
    lambda x: 'Other' if str(x).lower() == 'Refused'.lower() else x)

drive_selfcar_df['Gender'].unique()
# Out:
# array(['Man', 'Woman', 'Other'], dtype=object)

# %%
drive_selfcar_df['Age'].unique()
# Out:
# array(['65+', '30-49', '50-64', '18-29', 'Refused'], dtype=object)

# %%
drive_selfcar_df['Age'] = drive_selfcar_df['Age'].apply(
    lambda x: 0 if str(x).lower() == 'Refused'.lower() else x)
drive_selfcar_df['Age'].unique()
# Out:
# array(['65+', '30-49', '50-64', '18-29', 0], dtype=object)

# %%
drive_selfcar_df['Widespread_use_SelfDrive_Car'].unique()
# Out:
# array(['Not sure', 'Good idea for society', 'Bad idea for society',
#        'Refused'], dtype=object)

# %%
def society_income_influence(row):
    if row['Widespread_use_SelfDrive_Car'] == 'Good idea for society' and row['Accident_SelfDrive_Car'] == 'Increase the number of people killed or injured in traffic accidents':
        return 'Contrary Opinion'
    elif row['Widespread_use_SelfDrive_Car'] == 'Good idea for society' and row['Accident_SelfDrive_Car'] == 'Decrease the number of people killed or injured in traffic accidents':
        return 'Similar Opinion'
    elif row['Widespread_use_SelfDrive_Car'] == 'Bad idea for society' and row['Accident_SelfDrive_Car'] == 'Increase the number of people killed or injured in traffic accidents':
        return 'Similar Opinion'
    elif row['Widespread_use_SelfDrive_Car'] == 'Bad idea for society' and row['Accident_SelfDrive_Car'] == 'Decrease the number of people killed or injured in traffic accidents':
        return 'Contrary Opinion'
    else:
        return 'No Popular Opinion'

drive_selfcar_df['Preference_basedon_accident'] = drive_selfcar_df.apply(society_income_influence, axis=1)
drive_selfcar_df
# Out:
#        Question_key Interview_start_time  Interview_end_time Device_Type  \
# 1            100314  2021-11-04 12:35:35 2021-11-04 12:55:29  Smartphone
# 2            100363  2021-11-03 20:23:43 2021-11-03 20:36:24  Smartphone
# 5            100803  2021-11-03 19:22:44 2021-11-03 19:41:04   Laptop/PC
# 6            101224  2021-11-03 18:18:21 2021-11-03 18:33:41  Smartphone
# 8            101485  2021-11-02 19:22:24 2021-11-02 19:35:23  Smartphone
# ...             ...                  ...                 ...         ...
# 10252  202101013187  2021-11-03 18:50:06 2021-11-03 19:02:32   Laptop/PC
# 10253  202101013227  2021-11-02 14:27:17 2021-11-02 15:01:43  Smartphone
# 10257  202101013344  2021-11-04 16:30:29 2021-11-06 11:08:56  Smartphone
# 10258  202101013446  2021-11-06 15:22:13 2021-11-06 16:10:36   Laptop/PC
# 10259  202101013477  2021-11-02 23:46:38 2021-11-02 23:56:21  Smartphone
#
#       Language Read_about_SelfDrive_Car Widespread_use_SelfDrive_Car  \
# 1      English                 A little                     Not sure
# 2      English                 A little        Good idea for society
# 5      English                 A little         Bad idea for society
# 6      English                 A little         Bad idea for society
# 8      English                 A little         Bad idea for society
# ...        ...                      ...                          ...
# 10252  English                 A little         Bad idea for society
# 10253  English                    A lot                     Not sure
# 10257  English                    A lot        Good idea for society
# 10258  English                 A little        Good idea for society
# 10259  English                 A little                     Not sure
#
#       Choice_drive_SelfDrive_Car Passenger_SelfDrive_Car_CaseA  \
# 1              Probably NOT want         Probably would happen
# 2                  Probably want       Definitely would happen
# 5            Definitely NOT want     Probably would NOT happen
# 6              Probably NOT want     Probably would NOT happen
# 8              Probably NOT want     Probably would NOT happen
# ...                          ...                           ...
# 10252          Probably NOT want         Probably would happen
# 10253        Definitely NOT want         Probably would happen
# 10257            Definitely want       Definitely would happen
# 10258            Definitely want       Definitely would happen
# 10259          Probably NOT want     Probably would NOT happen
#
#       Passenger_SelfDrive_Car_CaseB  ...  \
# 1             Probably would happen  ...
# 2           Definitely would happen  ...
# 5           Definitely would happen  ...
# 6             Probably would happen  ...
# 8         Probably would NOT happen  ...
# ...                             ...  ...
# 10252       Definitely would happen  ...
# 10253       Definitely would happen  ...
# 10257       Definitely would happen  ...
# 10258         Probably would happen  ...
# 10259     Probably would NOT happen  ...
#
#                                    Birthplace         Marital_Status  \
# 1      U.S. – 50 states, District of Columbia               Divorced
# 2      U.S. – 50 states, District of Columbia                Married
# 5      U.S. – 50 states, District of Columbia                Married
# 6      U.S. – 50 states, District of Columbia                Married
# 8      U.S. – 50 states, District of Columbia                Widowed
# ...                                       ...                    ...
# 10252                         Another country                Married
# 10253  U.S. – 50 states, District of Columbia                Married
# 10257  U.S. – 50 states, District of Columbia  Living with a partner
# 10258  U.S. – 50 states, District of Columbia                Married
# 10259  U.S. – 50 states, District of Columbia                Married
#
#         Income_Level                             Vote_Registered_Adress  \
# 1      40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 2             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 5             100000  You are ABSOLUTELY CERTAIN that you are regist...
# 6      40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 8             100000  You are ABSOLUTELY CERTAIN that you are regist...
# ...              ...                                                ...
# 10252          30000  You are NOT registered to vote at your current...
# 10253  50000 - 60000  You are NOT registered to vote at your current...
# 10257          30000  You are ABSOLUTELY CERTAIN that you are regist...
# 10258  40000 - 50000  You are ABSOLUTELY CERTAIN that you are regist...
# 10259         100000  You are ABSOLUTELY CERTAIN that you are regist...
#
#            Ideology Interaction_Frequency Volume_Sum   Income_Class  \
# 1           Liberal   Several times a day        Yes  Middle income
# 2          Moderate   Several times a day         No   Upper income
# 5      Conservative  Several times a week        Yes   Upper income
# 6      Conservative      About once a day        Yes  Middle income
# 8      Conservative     Almost constantly        Yes   Upper income
# ...             ...                   ...        ...            ...
# 10252      Moderate     Almost constantly        Yes   Lower income
# 10253       Refused  Several times a week         No  Middle income
# 10257       Liberal     Almost constantly        Yes   Lower income
# 10258      Moderate   Several times a day         No  Middle income
# 10259  Conservative   Several times a day        Yes   Upper income
#
#       Weight_99_Percent Preference_basedon_accident
# 1              0.315090          No Popular Opinion
# 2              0.829579             Similar Opinion
# 5              0.302004             Similar Opinion
# 6              0.287719          No Popular Opinion
# 8              0.276541             Similar Opinion
# ...                 ...                         ...
# 10252          1.230882             Similar Opinion
# 10253          8.524234          No Popular Opinion
# 10257          0.282079            Contrary Opinion
# 10258          0.441525             Similar Opinion
# 10259          0.908670          No Popular Opinion
#
# [4876 rows x 52 columns]

# %%
drive_selfcar_df['Preference_basedon_accident'].unique()
# Out:
# array(['No Popular Opinion', 'Similar Opinion', 'Contrary Opinion'],
#       dtype=object)
